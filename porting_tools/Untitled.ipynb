# %%
numeric_cols = dict()

# %%
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['call_center']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_page']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_returns']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['catalog_sales']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_address']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['customer_demographics']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['date_dim']= []
numeric_cols['dbgen_version']= []
numeric_cols['dbgen_version']= []
numeric_cols['dbgen_version']= []
numeric_cols['dbgen_version']= []
numeric_cols['household_demographics']= []
numeric_cols['household_demographics']= []
numeric_cols['household_demographics']= []
numeric_cols['household_demographics']= []
numeric_cols['household_demographics']= []
numeric_cols['income_band']= []
numeric_cols['income_band']= []
numeric_cols['income_band']= []
numeric_cols['inventory']= []
numeric_cols['inventory']= []
numeric_cols['inventory']= []
numeric_cols['inventory']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['item']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['promotion']= []
numeric_cols['reason']= []
numeric_cols['reason']= []
numeric_cols['reason']= []
numeric_cols['ship_mode']= []
numeric_cols['ship_mode']= []
numeric_cols['ship_mode']= []
numeric_cols['ship_mode']= []
numeric_cols['ship_mode']= []
numeric_cols['ship_mode']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_returns']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['store_sales']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['time_dim']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['warehouse']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_page']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_returns']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_sales']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []
numeric_cols['web_site']= []

# %%
                        
numeric_cols['call_center'].append('cc_gmt_offset')               
numeric_cols['call_center'].append('cc_tax_percentage')                                                                                
numeric_cols['catalog_returns'].append('cr_return_amount')            
numeric_cols['catalog_returns'].append('cr_return_tax')               
numeric_cols['catalog_returns'].append('cr_return_amt_inc_tax')       
numeric_cols['catalog_returns'].append('cr_fee')                      
numeric_cols['catalog_returns'].append('cr_return_ship_cost')         
numeric_cols['catalog_returns'].append('cr_refunded_cash')            
numeric_cols['catalog_returns'].append('cr_reversed_charge')          
numeric_cols['catalog_returns'].append('cr_store_credit')             
numeric_cols['catalog_returns'].append('cr_net_loss')                                                                          
numeric_cols['catalog_sales'].append('cs_wholesale_cost')           
numeric_cols['catalog_sales'].append('cs_list_price')               
numeric_cols['catalog_sales'].append('cs_sales_price')              
numeric_cols['catalog_sales'].append('cs_ext_discount_amt')         
numeric_cols['catalog_sales'].append('cs_ext_sales_price')          
numeric_cols['catalog_sales'].append('cs_ext_wholesale_cost')       
numeric_cols['catalog_sales'].append('cs_ext_list_price')           
numeric_cols['catalog_sales'].append('cs_ext_tax')                  
numeric_cols['catalog_sales'].append('cs_coupon_amt')               
numeric_cols['catalog_sales'].append('cs_ext_ship_cost')            
numeric_cols['catalog_sales'].append('cs_net_paid')                 
numeric_cols['catalog_sales'].append('cs_net_paid_inc_tax')         
numeric_cols['catalog_sales'].append('cs_net_paid_inc_ship')        
numeric_cols['catalog_sales'].append('cs_net_paid_inc_ship_tax')    
numeric_cols['catalog_sales'].append('cs_net_profit')                                                
numeric_cols[ 'customer_address'].append('ca_gmt_offset')                                                                                                                  
numeric_cols['item'].append('i_current_price')             
numeric_cols['item'].append('i_wholesale_cost')                                       
numeric_cols['promotion'].append('p_cost')                                                    
numeric_cols['store'].append('s_gmt_offset')                
numeric_cols['store'].append('s_tax_precentage')                                             
numeric_cols['store_returns'].append('sr_return_amt')               
numeric_cols['store_returns'].append('sr_return_tax')               
numeric_cols['store_returns'].append('sr_return_amt_inc_tax')       
numeric_cols['store_returns'].append('sr_fee')                      
numeric_cols['store_returns'].append('sr_return_ship_cost')         
numeric_cols['store_returns'].append('sr_refunded_cash')            
numeric_cols['store_returns'].append('sr_reversed_charge')          
numeric_cols['store_returns'].append('sr_store_credit')             
numeric_cols['store_returns'].append('sr_net_loss')                                                  
numeric_cols['store_sales'].append('ss_wholesale_cost')           
numeric_cols['store_sales'].append('ss_list_price')               
numeric_cols['store_sales'].append('ss_sales_price')              
numeric_cols['store_sales'].append('ss_ext_discount_amt')         
numeric_cols['store_sales'].append('ss_ext_sales_price')          
numeric_cols['store_sales'].append('ss_ext_wholesale_cost')       
numeric_cols['store_sales'].append('ss_ext_list_price')           
numeric_cols['store_sales'].append('ss_ext_tax')                  
numeric_cols['store_sales'].append('ss_coupon_amt')               
numeric_cols['store_sales'].append('ss_net_paid')                 
numeric_cols['store_sales'].append('ss_net_paid_inc_tax')         
numeric_cols['store_sales'].append('ss_net_profit')                                    
numeric_cols['warehouse'].append('w_gmt_offset')                                                                                     
numeric_cols['web_returns'].append('wr_return_amt')               
numeric_cols['web_returns'].append('wr_return_tax')               
numeric_cols['web_returns'].append('wr_return_amt_inc_tax')       
numeric_cols['web_returns'].append('wr_fee')                      
numeric_cols['web_returns'].append('wr_return_ship_cost')         
numeric_cols['web_returns'].append('wr_refunded_cash')            
numeric_cols['web_returns'].append('wr_reversed_charge')          
numeric_cols['web_returns'].append('wr_account_credit')           
numeric_cols['web_returns'].append('wr_net_loss')                                                                          
numeric_cols['web_sales'].append('ws_wholesale_cost')           
numeric_cols['web_sales'].append('ws_list_price')               
numeric_cols['web_sales'].append('ws_sales_price')              
numeric_cols['web_sales'].append('ws_ext_discount_amt')         
numeric_cols['web_sales'].append('ws_ext_sales_price')          
numeric_cols['web_sales'].append('ws_ext_wholesale_cost')       
numeric_cols['web_sales'].append('ws_ext_list_price')           
numeric_cols['web_sales'].append('ws_ext_tax')                  
numeric_cols['web_sales'].append('ws_coupon_amt')               
numeric_cols['web_sales'].append('ws_ext_ship_cost')            
numeric_cols['web_sales'].append('ws_net_paid')                 
numeric_cols['web_sales'].append('ws_net_paid_inc_tax')         
numeric_cols['web_sales'].append('ws_net_paid_inc_ship')        
numeric_cols['web_sales'].append('ws_net_paid_inc_ship_tax')    
numeric_cols['web_sales'].append('ws_net_profit')                              
numeric_cols['web_site'].append('web_gmt_offset')              
numeric_cols['web_site'].append('web_tax_percentage')

# %%
numeric_cols
# Out:
# {'call_center': ['cc_gmt_offset', 'cc_tax_percentage'],
#  'catalog_returns': ['cr_return_amount',
#   'cr_return_tax',
#   'cr_return_amt_inc_tax',
#   'cr_fee',
#   'cr_return_ship_cost',
#   'cr_refunded_cash',
#   'cr_reversed_charge',
#   'cr_store_credit',
#   'cr_net_loss'],
#  'catalog_sales': ['cs_wholesale_cost',
#   'cs_list_price',
#   'cs_sales_price',
#   'cs_ext_discount_amt',
#   'cs_ext_sales_price',
#   'cs_ext_wholesale_cost',
#   'cs_ext_list_price',
#   'cs_ext_tax',
#   'cs_coupon_amt',
#   'cs_ext_ship_cost',
#   'cs_net_paid',
#   'cs_net_paid_inc_tax',
#   'cs_net_paid_inc_ship',
#   'cs_net_paid_inc_ship_tax',
#   'cs_net_profit'],
#  'customer_address': ['ca_gmt_offset'],
#  'item': ['i_current_price', 'i_wholesale_cost'],
#  'promotion': ['p_cost'],
#  'store': ['s_gmt_offset', 's_tax_precentage'],
#  'store_returns': ['sr_return_amt',
#   'sr_return_tax',
#   'sr_return_amt_inc_tax',
#   'sr_fee',
#   'sr_return_ship_cost',
#   'sr_refunded_cash',
# ...

# %%
all_cols = dict()
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['call_center']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_page']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_returns']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['catalog_sales']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_address']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['customer_demographics']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['date_dim']= []
all_cols['dbgen_version']= []
all_cols['dbgen_version']= []
all_cols['dbgen_version']= []
all_cols['dbgen_version']= []
all_cols['household_demographics']= []
all_cols['household_demographics']= []
all_cols['household_demographics']= []
all_cols['household_demographics']= []
all_cols['household_demographics']= []
all_cols['income_band']= []
all_cols['income_band']= []
all_cols['income_band']= []
all_cols['inventory']= []
all_cols['inventory']= []
all_cols['inventory']= []
all_cols['inventory']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['item']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['promotion']= []
all_cols['reason']= []
all_cols['reason']= []
all_cols['reason']= []
all_cols['ship_mode']= []
all_cols['ship_mode']= []
all_cols['ship_mode']= []
all_cols['ship_mode']= []
all_cols['ship_mode']= []
all_cols['ship_mode']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_returns']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['store_sales']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['time_dim']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['warehouse']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_page']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_returns']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_sales']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []
all_cols['web_site']= []

# %%
all_cols['call_center'].append('cc_call_center_sk')        
all_cols['call_center'].append('cc_call_center_id')        
all_cols['call_center'].append('cc_rec_start_date')        
all_cols['call_center'].append('cc_rec_end_date')          
all_cols['call_center'].append('cc_closed_date_sk')        
all_cols['call_center'].append('cc_open_date_sk')          
all_cols['call_center'].append('cc_name')                  
all_cols['call_center'].append('cc_class')                 
all_cols['call_center'].append('cc_employees')             
all_cols['call_center'].append('cc_sq_ft')                 
all_cols['call_center'].append('cc_hours')                 
all_cols['call_center'].append('cc_manager')               
all_cols['call_center'].append('cc_mkt_id')                
all_cols['call_center'].append('cc_mkt_class')             
all_cols['call_center'].append('cc_mkt_desc')              
all_cols['call_center'].append('cc_market_manager')        
all_cols['call_center'].append('cc_division')              
all_cols['call_center'].append('cc_division_name')         
all_cols['call_center'].append('cc_company')               
all_cols['call_center'].append('cc_company_name')          
all_cols['call_center'].append('cc_street_number')         
all_cols['call_center'].append('cc_street_name')           
all_cols['call_center'].append('cc_street_type')           
all_cols['call_center'].append('cc_suite_number')          
all_cols['call_center'].append('cc_city')                  
all_cols['call_center'].append('cc_county')                
all_cols['call_center'].append('cc_state')                 
all_cols['call_center'].append('cc_zip')                   
all_cols['call_center'].append('cc_country')               
all_cols['call_center'].append('cc_gmt_offset')            
all_cols['call_center'].append('cc_tax_percentage')        
all_cols['catalog_page'].append('cp_catalog_page_sk')       
all_cols['catalog_page'].append('cp_catalog_page_id')       
all_cols['catalog_page'].append('cp_start_date_sk')         
all_cols['catalog_page'].append('cp_end_date_sk')           
all_cols['catalog_page'].append('cp_department')            
all_cols['catalog_page'].append('cp_catalog_number')        
all_cols['catalog_page'].append('cp_catalog_page_number')   
all_cols['catalog_page'].append('cp_description')           
all_cols['catalog_page'].append('cp_type')                  
all_cols['catalog_returns'].append('cr_returned_date_sk')      
all_cols['catalog_returns'].append('cr_returned_time_sk')      
all_cols['catalog_returns'].append('cr_item_sk')               
all_cols['catalog_returns'].append('cr_refunded_customer_sk')  
all_cols['catalog_returns'].append('cr_refunded_cdemo_sk')     
all_cols['catalog_returns'].append('cr_refunded_hdemo_sk')     
all_cols['catalog_returns'].append('cr_refunded_addr_sk')      
all_cols['catalog_returns'].append('cr_returning_customer_sk') 
all_cols['catalog_returns'].append('cr_returning_cdemo_sk')    
all_cols['catalog_returns'].append('cr_returning_hdemo_sk')    
all_cols['catalog_returns'].append('cr_returning_addr_sk')     
all_cols['catalog_returns'].append('cr_call_center_sk')        
all_cols['catalog_returns'].append('cr_catalog_page_sk')       
all_cols['catalog_returns'].append('cr_ship_mode_sk')          
all_cols['catalog_returns'].append('cr_warehouse_sk')          
all_cols['catalog_returns'].append('cr_reason_sk')             
all_cols['catalog_returns'].append('cr_order_number')          
all_cols['catalog_returns'].append('cr_return_quantity')       
all_cols['catalog_returns'].append('cr_return_amount')         
all_cols['catalog_returns'].append('cr_return_tax')            
all_cols['catalog_returns'].append('cr_return_amt_inc_tax')    
all_cols['catalog_returns'].append('cr_fee')                   
all_cols['catalog_returns'].append('cr_return_ship_cost')      
all_cols['catalog_returns'].append('cr_refunded_cash')         
all_cols['catalog_returns'].append('cr_reversed_charge')       
all_cols['catalog_returns'].append('cr_store_credit')          
all_cols['catalog_returns'].append('cr_net_loss')              
all_cols['catalog_sales'].append('cs_sold_date_sk')          
all_cols['catalog_sales'].append('cs_sold_time_sk')          
all_cols['catalog_sales'].append('cs_ship_date_sk')          
all_cols['catalog_sales'].append('cs_bill_customer_sk')      
all_cols['catalog_sales'].append('cs_bill_cdemo_sk')         
all_cols['catalog_sales'].append('cs_bill_hdemo_sk')         
all_cols['catalog_sales'].append('cs_bill_addr_sk')          
all_cols['catalog_sales'].append('cs_ship_customer_sk')      
all_cols['catalog_sales'].append('cs_ship_cdemo_sk')         
all_cols['catalog_sales'].append('cs_ship_hdemo_sk')         
all_cols['catalog_sales'].append('cs_ship_addr_sk')          
all_cols['catalog_sales'].append('cs_call_center_sk')        
all_cols['catalog_sales'].append('cs_catalog_page_sk')       
all_cols['catalog_sales'].append('cs_ship_mode_sk')          
all_cols['catalog_sales'].append('cs_warehouse_sk')          
all_cols['catalog_sales'].append('cs_item_sk')               
all_cols['catalog_sales'].append('cs_promo_sk')              
all_cols['catalog_sales'].append('cs_order_number')          
all_cols['catalog_sales'].append('cs_quantity')              
all_cols['catalog_sales'].append('cs_wholesale_cost')        
all_cols['catalog_sales'].append('cs_list_price')            
all_cols['catalog_sales'].append('cs_sales_price')           
all_cols['catalog_sales'].append('cs_ext_discount_amt')      
all_cols['catalog_sales'].append('cs_ext_sales_price')       
all_cols['catalog_sales'].append('cs_ext_wholesale_cost')    
all_cols['catalog_sales'].append('cs_ext_list_price')        
all_cols['catalog_sales'].append('cs_ext_tax')               
all_cols['catalog_sales'].append('cs_coupon_amt')            
all_cols['catalog_sales'].append('cs_ext_ship_cost')         
all_cols['catalog_sales'].append('cs_net_paid')              
all_cols['catalog_sales'].append('cs_net_paid_inc_tax')      
all_cols['catalog_sales'].append('cs_net_paid_inc_ship')     
all_cols['catalog_sales'].append('cs_net_paid_inc_ship_tax') 
all_cols['catalog_sales'].append('cs_net_profit')            
all_cols['customer'].append('c_customer_sk')            
all_cols['customer'].append('c_customer_id')            
all_cols['customer'].append('c_current_cdemo_sk')       
all_cols['customer'].append('c_current_hdemo_sk')       
all_cols['customer'].append('c_current_addr_sk')        
all_cols['customer'].append('c_first_shipto_date_sk')   
all_cols['customer'].append('c_first_sales_date_sk')    
all_cols['customer'].append('c_salutation')             
all_cols['customer'].append('c_first_name')             
all_cols['customer'].append('c_last_name')              
all_cols['customer'].append('c_preferred_cust_flag')    
all_cols['customer'].append('c_birth_day')              
all_cols['customer'].append('c_birth_month')            
all_cols['customer'].append('c_birth_year')             
all_cols['customer'].append('c_birth_country')          
all_cols['customer'].append('c_login')                  
all_cols['customer'].append('c_email_address')          
all_cols['customer'].append('c_last_review_date_sk')    
all_cols['customer_address'].append('ca_address_sk')            
all_cols['customer_address'].append('ca_address_id')            
all_cols['customer_address'].append('ca_street_number')         
all_cols['customer_address'].append('ca_street_name')           
all_cols['customer_address'].append('ca_street_type')           
all_cols['customer_address'].append('ca_suite_number')          
all_cols['customer_address'].append('ca_city')                  
all_cols['customer_address'].append('ca_county')                
all_cols['customer_address'].append('ca_state')                 
all_cols['customer_address'].append('ca_zip')                   
all_cols['customer_address'].append('ca_country')               
all_cols['customer_address'].append('ca_gmt_offset')            
all_cols['customer_address'].append('ca_location_type')         
all_cols['customer_demographics'].append('cd_demo_sk')               
all_cols['customer_demographics'].append('cd_gender')                
all_cols['customer_demographics'].append('cd_marital_status')        
all_cols['customer_demographics'].append('cd_education_status')      
all_cols['customer_demographics'].append('cd_purchase_estimate')     
all_cols['customer_demographics'].append('cd_credit_rating')         
all_cols['customer_demographics'].append('cd_dep_count')             
all_cols['customer_demographics'].append('cd_dep_employed_count')    
all_cols['customer_demographics'].append('cd_dep_college_count')     
all_cols['date_dim'].append('d_date_sk')                
all_cols['date_dim'].append('d_date_id')                
all_cols['date_dim'].append('d_date')                   
all_cols['date_dim'].append('d_month_seq')              
all_cols['date_dim'].append('d_week_seq')               
all_cols['date_dim'].append('d_quarter_seq')            
all_cols['date_dim'].append('d_year')                   
all_cols['date_dim'].append('d_dow')                    
all_cols['date_dim'].append('d_moy')                    
all_cols['date_dim'].append('d_dom')                    
all_cols['date_dim'].append('d_qoy')                    
all_cols['date_dim'].append('d_fy_year')                
all_cols['date_dim'].append('d_fy_quarter_seq')         
all_cols['date_dim'].append('d_fy_week_seq')            
all_cols['date_dim'].append('d_day_name')               
all_cols['date_dim'].append('d_quarter_name')           
all_cols['date_dim'].append('d_holiday')                
all_cols['date_dim'].append('d_weekend')                
all_cols['date_dim'].append('d_following_holiday')      
all_cols['date_dim'].append('d_first_dom')              
all_cols['date_dim'].append('d_last_dom')               
all_cols['date_dim'].append('d_same_day_ly')            
all_cols['date_dim'].append('d_same_day_lq')            
all_cols['date_dim'].append('d_current_day')            
all_cols['date_dim'].append('d_current_week')           
all_cols['date_dim'].append('d_current_month')          
all_cols['date_dim'].append('d_current_quarter')        
all_cols['date_dim'].append('d_current_year')           
all_cols['dbgen_version'].append('dv_version')               
all_cols['dbgen_version'].append('dv_create_date')           
all_cols['dbgen_version'].append('dv_create_time')           
all_cols['dbgen_version'].append('dv_cmdline_args')          
all_cols['household_demographics'].append('hd_demo_sk')               
all_cols['household_demographics'].append('hd_income_band_sk')        
all_cols['household_demographics'].append('hd_buy_potential')         
all_cols['household_demographics'].append('hd_dep_count')             
all_cols['household_demographics'].append('hd_vehicle_count')         
all_cols['income_band'].append('ib_income_band_sk')        
all_cols['income_band'].append('ib_lower_bound')           
all_cols['income_band'].append('ib_upper_bound')           
all_cols['inventory'].append('inv_date_sk')              
all_cols['inventory'].append('inv_item_sk')              
all_cols['inventory'].append('inv_warehouse_sk')         
all_cols['inventory'].append('inv_quantity_on_hand')     
all_cols['item'].append('i_item_sk')                
all_cols['item'].append('i_item_id')                
all_cols['item'].append('i_rec_start_date')         
all_cols['item'].append('i_rec_end_date')           
all_cols['item'].append('i_item_desc')              
all_cols['item'].append('i_current_price')          
all_cols['item'].append('i_wholesale_cost')         
all_cols['item'].append('i_brand_id')               
all_cols['item'].append('i_brand')                  
all_cols['item'].append('i_class_id')               
all_cols['item'].append('i_class')                  
all_cols['item'].append('i_category_id')            
all_cols['item'].append('i_category')               
all_cols['item'].append('i_manufact_id')            
all_cols['item'].append('i_manufact')               
all_cols['item'].append('i_size')                   
all_cols['item'].append('i_formulation')            
all_cols['item'].append('i_color')                  
all_cols['item'].append('i_units')                  
all_cols['item'].append('i_container')              
all_cols['item'].append('i_manager_id')             
all_cols['item'].append('i_product_name')           
all_cols['promotion'].append('p_promo_sk')               
all_cols['promotion'].append('p_promo_id')               
all_cols['promotion'].append('p_start_date_sk')          
all_cols['promotion'].append('p_end_date_sk')            
all_cols['promotion'].append('p_item_sk')                
all_cols['promotion'].append('p_cost')                   
all_cols['promotion'].append('p_response_target')        
all_cols['promotion'].append('p_promo_name')             
all_cols['promotion'].append('p_channel_dmail')          
all_cols['promotion'].append('p_channel_email')          
all_cols['promotion'].append('p_channel_catalog')        
all_cols['promotion'].append('p_channel_tv')             
all_cols['promotion'].append('p_channel_radio')          
all_cols['promotion'].append('p_channel_press')          
all_cols['promotion'].append('p_channel_event')          
all_cols['promotion'].append('p_channel_demo')           
all_cols['promotion'].append('p_channel_details')        
all_cols['promotion'].append('p_purpose')                
all_cols['promotion'].append('p_discount_active')        
all_cols['reason'].append('r_reason_sk')              
all_cols['reason'].append('r_reason_id')              
all_cols['reason'].append('r_reason_desc')            
all_cols['ship_mode'].append('sm_ship_mode_sk')          
all_cols['ship_mode'].append('sm_ship_mode_id')          
all_cols['ship_mode'].append('sm_type')                  
all_cols['ship_mode'].append('sm_code')                  
all_cols['ship_mode'].append('sm_carrier')               
all_cols['ship_mode'].append('sm_contract')              
all_cols['store'].append('s_store_sk')               
all_cols['store'].append('s_store_id')               
all_cols['store'].append('s_rec_start_date')         
all_cols['store'].append('s_rec_end_date')           
all_cols['store'].append('s_closed_date_sk')         
all_cols['store'].append('s_store_name')             
all_cols['store'].append('s_number_employees')       
all_cols['store'].append('s_floor_space')            
all_cols['store'].append('s_hours')                  
all_cols['store'].append('s_manager')                
all_cols['store'].append('s_market_id')              
all_cols['store'].append('s_geography_class')        
all_cols['store'].append('s_market_desc')            
all_cols['store'].append('s_market_manager')         
all_cols['store'].append('s_division_id')            
all_cols['store'].append('s_division_name')          
all_cols['store'].append('s_company_id')             
all_cols['store'].append('s_company_name')           
all_cols['store'].append('s_street_number')          
all_cols['store'].append('s_street_name')            
all_cols['store'].append('s_street_type')            
all_cols['store'].append('s_suite_number')           
all_cols['store'].append('s_city')                   
all_cols['store'].append('s_county')                 
all_cols['store'].append('s_state')                  
all_cols['store'].append('s_zip')                    
all_cols['store'].append('s_country')                
all_cols['store'].append('s_gmt_offset')             
all_cols['store'].append('s_tax_precentage')         
all_cols['store_returns'].append('sr_returned_date_sk')      
all_cols['store_returns'].append('sr_return_time_sk')        
all_cols['store_returns'].append('sr_item_sk')               
all_cols['store_returns'].append('sr_customer_sk')           
all_cols['store_returns'].append('sr_cdemo_sk')              
all_cols['store_returns'].append('sr_hdemo_sk')              
all_cols['store_returns'].append('sr_addr_sk')               
all_cols['store_returns'].append('sr_store_sk')              
all_cols['store_returns'].append('sr_reason_sk')             
all_cols['store_returns'].append('sr_ticket_number')         
all_cols['store_returns'].append('sr_return_quantity')       
all_cols['store_returns'].append('sr_return_amt')            
all_cols['store_returns'].append('sr_return_tax')            
all_cols['store_returns'].append('sr_return_amt_inc_tax')    
all_cols['store_returns'].append('sr_fee')                   
all_cols['store_returns'].append('sr_return_ship_cost')      
all_cols['store_returns'].append('sr_refunded_cash')         
all_cols['store_returns'].append('sr_reversed_charge')       
all_cols['store_returns'].append('sr_store_credit')          
all_cols['store_returns'].append('sr_net_loss')              
all_cols['store_sales'].append('ss_sold_date_sk')          
all_cols['store_sales'].append('ss_sold_time_sk')          
all_cols['store_sales'].append('ss_item_sk')               
all_cols['store_sales'].append('ss_customer_sk')           
all_cols['store_sales'].append('ss_cdemo_sk')              
all_cols['store_sales'].append('ss_hdemo_sk')              
all_cols['store_sales'].append('ss_addr_sk')               
all_cols['store_sales'].append('ss_store_sk')              
all_cols['store_sales'].append('ss_promo_sk')              
all_cols['store_sales'].append('ss_ticket_number')         
all_cols['store_sales'].append('ss_quantity')              
all_cols['store_sales'].append('ss_wholesale_cost')        
all_cols['store_sales'].append('ss_list_price')            
all_cols['store_sales'].append('ss_sales_price')           
all_cols['store_sales'].append('ss_ext_discount_amt')      
all_cols['store_sales'].append('ss_ext_sales_price')       
all_cols['store_sales'].append('ss_ext_wholesale_cost')    
all_cols['store_sales'].append('ss_ext_list_price')        
all_cols['store_sales'].append('ss_ext_tax')               
all_cols['store_sales'].append('ss_coupon_amt')            
all_cols['store_sales'].append('ss_net_paid')              
all_cols['store_sales'].append('ss_net_paid_inc_tax')      
all_cols['store_sales'].append('ss_net_profit')            
all_cols['time_dim'].append('t_time_sk')                
all_cols['time_dim'].append('t_time_id')                
all_cols['time_dim'].append('t_time')                   
all_cols['time_dim'].append('t_hour')                   
all_cols['time_dim'].append('t_minute')                 
all_cols['time_dim'].append('t_second')                 
all_cols['time_dim'].append('t_am_pm')                  
all_cols['time_dim'].append('t_shift')                  
all_cols['time_dim'].append('t_sub_shift')              
all_cols['time_dim'].append('t_meal_time')              
all_cols['warehouse'].append('w_warehouse_sk')           
all_cols['warehouse'].append('w_warehouse_id')           
all_cols['warehouse'].append('w_warehouse_name')         
all_cols['warehouse'].append('w_warehouse_sq_ft')        
all_cols['warehouse'].append('w_street_number')          
all_cols['warehouse'].append('w_street_name')            
all_cols['warehouse'].append('w_street_type')            
all_cols['warehouse'].append('w_suite_number')           
all_cols['warehouse'].append('w_city')                   
all_cols['warehouse'].append('w_county')                 
all_cols['warehouse'].append('w_state')                  
all_cols['warehouse'].append('w_zip')                    
all_cols['warehouse'].append('w_country')                
all_cols['warehouse'].append('w_gmt_offset')             
all_cols['web_page'].append('wp_web_page_sk')           
all_cols['web_page'].append('wp_web_page_id')           
all_cols['web_page'].append('wp_rec_start_date')        
all_cols['web_page'].append('wp_rec_end_date')          
all_cols['web_page'].append('wp_creation_date_sk')      
all_cols['web_page'].append('wp_access_date_sk')        
all_cols['web_page'].append('wp_autogen_flag')          
all_cols['web_page'].append('wp_customer_sk')           
all_cols['web_page'].append('wp_url')                   
all_cols['web_page'].append('wp_type')                  
all_cols['web_page'].append('wp_char_count')            
all_cols['web_page'].append('wp_link_count')            
all_cols['web_page'].append('wp_image_count')           
all_cols['web_page'].append('wp_max_ad_count')          
all_cols['web_returns'].append('wr_returned_date_sk')      
all_cols['web_returns'].append('wr_returned_time_sk')      
all_cols['web_returns'].append('wr_item_sk')               
all_cols['web_returns'].append('wr_refunded_customer_sk')  
all_cols['web_returns'].append('wr_refunded_cdemo_sk')     
all_cols['web_returns'].append('wr_refunded_hdemo_sk')     
all_cols['web_returns'].append('wr_refunded_addr_sk')      
all_cols['web_returns'].append('wr_returning_customer_sk') 
all_cols['web_returns'].append('wr_returning_cdemo_sk')    
all_cols['web_returns'].append('wr_returning_hdemo_sk')    
all_cols['web_returns'].append('wr_returning_addr_sk')     
all_cols['web_returns'].append('wr_web_page_sk')           
all_cols['web_returns'].append('wr_reason_sk')             
all_cols['web_returns'].append('wr_order_number')          
all_cols['web_returns'].append('wr_return_quantity')       
all_cols['web_returns'].append('wr_return_amt')            
all_cols['web_returns'].append('wr_return_tax')            
all_cols['web_returns'].append('wr_return_amt_inc_tax')    
all_cols['web_returns'].append('wr_fee')                   
all_cols['web_returns'].append('wr_return_ship_cost')      
all_cols['web_returns'].append('wr_refunded_cash')         
all_cols['web_returns'].append('wr_reversed_charge')       
all_cols['web_returns'].append('wr_account_credit')        
all_cols['web_returns'].append('wr_net_loss')              
all_cols['web_sales'].append('ws_sold_date_sk')          
all_cols['web_sales'].append('ws_sold_time_sk')          
all_cols['web_sales'].append('ws_ship_date_sk')          
all_cols['web_sales'].append('ws_item_sk')               
all_cols['web_sales'].append('ws_bill_customer_sk')      
all_cols['web_sales'].append('ws_bill_cdemo_sk')         
all_cols['web_sales'].append('ws_bill_hdemo_sk')         
all_cols['web_sales'].append('ws_bill_addr_sk')          
all_cols['web_sales'].append('ws_ship_customer_sk')      
all_cols['web_sales'].append('ws_ship_cdemo_sk')         
all_cols['web_sales'].append('ws_ship_hdemo_sk')         
all_cols['web_sales'].append('ws_ship_addr_sk')          
all_cols['web_sales'].append('ws_web_page_sk')           
all_cols['web_sales'].append('ws_web_site_sk')           
all_cols['web_sales'].append('ws_ship_mode_sk')          
all_cols['web_sales'].append('ws_warehouse_sk')          
all_cols['web_sales'].append('ws_promo_sk')              
all_cols['web_sales'].append('ws_order_number')          
all_cols['web_sales'].append('ws_quantity')              
all_cols['web_sales'].append('ws_wholesale_cost')        
all_cols['web_sales'].append('ws_list_price')            
all_cols['web_sales'].append('ws_sales_price')           
all_cols['web_sales'].append('ws_ext_discount_amt')      
all_cols['web_sales'].append('ws_ext_sales_price')       
all_cols['web_sales'].append('ws_ext_wholesale_cost')    
all_cols['web_sales'].append('ws_ext_list_price')        
all_cols['web_sales'].append('ws_ext_tax')               
all_cols['web_sales'].append('ws_coupon_amt')            
all_cols['web_sales'].append('ws_ext_ship_cost')         
all_cols['web_sales'].append('ws_net_paid')              
all_cols['web_sales'].append('ws_net_paid_inc_tax')      
all_cols['web_sales'].append('ws_net_paid_inc_ship')     
all_cols['web_sales'].append('ws_net_paid_inc_ship_tax') 
all_cols['web_sales'].append('ws_net_profit')            
all_cols['web_site'].append('web_site_sk')              
all_cols['web_site'].append('web_site_id')              
all_cols['web_site'].append('web_rec_start_date')       
all_cols['web_site'].append('web_rec_end_date')         
all_cols['web_site'].append('web_name')                 
all_cols['web_site'].append('web_open_date_sk')         
all_cols['web_site'].append('web_close_date_sk')        
all_cols['web_site'].append('web_class')                
all_cols['web_site'].append('web_manager')              
all_cols['web_site'].append('web_mkt_id')               
all_cols['web_site'].append('web_mkt_class')            
all_cols['web_site'].append('web_mkt_desc')             
all_cols['web_site'].append('web_market_manager')       
all_cols['web_site'].append('web_company_id')           
all_cols['web_site'].append('web_company_name')         
all_cols['web_site'].append('web_street_number')        
all_cols['web_site'].append('web_street_name')          
all_cols['web_site'].append('web_street_type')          
all_cols['web_site'].append('web_suite_number')         
all_cols['web_site'].append('web_city')                 
all_cols['web_site'].append('web_county')               
all_cols['web_site'].append('web_state')                
all_cols['web_site'].append('web_zip')                  
all_cols['web_site'].append('web_country')              
all_cols['web_site'].append('web_gmt_offset')           
all_cols['web_site'].append('web_tax_percentage')

# %%
all_cols
# Out:
# {'call_center': ['cc_call_center_sk',
#   'cc_call_center_id',
#   'cc_rec_start_date',
#   'cc_rec_end_date',
#   'cc_closed_date_sk',
#   'cc_open_date_sk',
#   'cc_name',
#   'cc_class',
#   'cc_employees',
#   'cc_sq_ft',
#   'cc_hours',
#   'cc_manager',
#   'cc_mkt_id',
#   'cc_mkt_class',
#   'cc_mkt_desc',
#   'cc_market_manager',
#   'cc_division',
#   'cc_division_name',
#   'cc_company',
#   'cc_company_name',
#   'cc_street_number',
#   'cc_street_name',
#   'cc_street_type',
#   'cc_suite_number',
#   'cc_city',
#   'cc_county',
#   'cc_state',
#   'cc_zip',
#   'cc_country',
#   'cc_gmt_offset',
#   'cc_tax_percentage'],
#  'catalog_page': ['cp_catalog_page_sk',
#   'cp_catalog_page_id',
#   'cp_start_date_sk',
#   'cp_end_date_sk',
#   'cp_department',
#   'cp_catalog_number',
#   'cp_catalog_page_number',
#   'cp_description',
#   'cp_type'],
#  'catalog_returns': ['cr_returned_date_sk',
#   'cr_returned_time_sk',
#   'cr_item_sk',
#   'cr_refunded_customer_sk',
# ...

# %%
categorical = dict()
for key in all_cols.keys() :
    for val in numeric_cols[key] :
        all_cols[key].remove(val)

# %%
test = [1,3,4]
test.remove(3)
test
# Out:
# [1, 4]

# %%
all_cols
# Out:
# {'call_center': ['cc_call_center_sk',
#   'cc_call_center_id',
#   'cc_rec_start_date',
#   'cc_rec_end_date',
#   'cc_closed_date_sk',
#   'cc_open_date_sk',
#   'cc_name',
#   'cc_class',
#   'cc_employees',
#   'cc_sq_ft',
#   'cc_hours',
#   'cc_manager',
#   'cc_mkt_id',
#   'cc_mkt_class',
#   'cc_mkt_desc',
#   'cc_market_manager',
#   'cc_division',
#   'cc_division_name',
#   'cc_company',
#   'cc_company_name',
#   'cc_street_number',
#   'cc_street_name',
#   'cc_street_type',
#   'cc_suite_number',
#   'cc_city',
#   'cc_county',
#   'cc_state',
#   'cc_zip',
#   'cc_country'],
#  'catalog_page': ['cp_catalog_page_sk',
#   'cp_catalog_page_id',
#   'cp_start_date_sk',
#   'cp_end_date_sk',
#   'cp_department',
#   'cp_catalog_number',
#   'cp_catalog_page_number',
#   'cp_description',
#   'cp_type'],
#  'catalog_returns': ['cr_returned_date_sk',
#   'cr_returned_time_sk',
#   'cr_item_sk',
#   'cr_refunded_customer_sk',
#   'cr_refunded_cdemo_sk',
# ...
